# %% [markdown]
# ## Markdown Cell -- Probably Table of Contents

# %%
#import statements

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
#loading dataframe

df = pd.read_csv('COVID-19_case_surveillance_wrangled.csv')
df.head()
# Out:
#   cdc_report_dt pos_spec_dt    onset_dt             current_status   sex  \
# 0    2020-11-14  2020-11-10  2020-11-10  Laboratory-confirmed case  Male
# 1    2020-11-19  2020-11-10  2020-11-09  Laboratory-confirmed case  Male
# 2    2020-11-13  2020-11-10  2020-11-10  Laboratory-confirmed case  Male
# 3    2020-11-09  2020-11-10  2020-11-09  Laboratory-confirmed case  Male
# 4    2020-11-06  2020-11-10  2020-11-06  Laboratory-confirmed case  Male
#
#        age_group   race_and_ethnicity hosp_yn icu_yn death_yn medcond_yn
# 0  10 - 19 Years  Black, Non-Hispanic      No     No       No         No
# 1  10 - 19 Years  Black, Non-Hispanic      No     No       No         No
# 2  10 - 19 Years  Black, Non-Hispanic      No     No       No        Yes
# 3  10 - 19 Years  Black, Non-Hispanic      No     No       No         No
# 4  10 - 19 Years  Black, Non-Hispanic      No     No       No        Yes

# %%
#looking at size of dataframe

df.shape
# Out:
# (294946, 11)

# %%
#examining datatypes

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294946 entries, 0 to 294945
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   cdc_report_dt       294946 non-null  object
#  1   pos_spec_dt         294946 non-null  object
#  2   onset_dt            294946 non-null  object
#  3   current_status      294946 non-null  object
#  4   sex                 294946 non-null  object
#  5   age_group           294946 non-null  object
#  6   race_and_ethnicity  294946 non-null  object
#  7   hosp_yn             294946 non-null  object
#  8   icu_yn              294946 non-null  object
#  9   death_yn            294946 non-null  object
#  10  medcond_yn          294946 non-null  object
# dtypes: object(11)
# memory usage: 24.8+ MB

# %% [markdown]
# ## Overview of Dataframe
#
# - Dataframe has 294,496 entries after wrangling, which had around 8,400,000 entries
# - Removed Missing, Unknown, and null values from original dataset.
# - Contains data from January 1, 2020 to November 19, 2020.

# %% [markdown]
# ## Explanation of Columns
#
# - cdc_report_dt: Date CDC reported
#
# - pos_spec_dt: Date of positive specimen collected
#
# - onset_dt: The start date when person experienced Covid-19 symtoms
#
# - current_status: Laboratory or confirmed case
#
# - sex: sex of person
#
# - age_group: demographic group of patient
#
# - race and ethnicity (combined): race and ethnicity of patient
#
# - hosp_yn: was patient hospitalized
#
# - icu_yn: was patient in ICU
#
# - death_yn: did patient die
#
# - medcond_yn: did patient have underlying conditions

# %%
#making a copy of dataframe df_wrangle

df_viz = df.copy()

# %%
#creating alternate death and medcond_columns to stage creation of death_with_medcond column

df_viz['death_yn_alt']=df_viz['death_yn'].replace({'Yes':1, 'No':0})
df_viz['medcond_yn_alt']=df_viz['medcond_yn'].replace({'Yes':1, 'No':0})

# %%
#creating death_with_medcond column

df_viz['death_with_medcond']= df_viz['medcond_yn_alt'] * df_viz['death_yn_alt']

# %%
#replacing values in death_with_medcond column with yes and no from 1 and 0, respectively

df_viz['death_with_medcond'] = df_viz['death_with_medcond'].replace({1:'Yes', 0:'No'})

# %%
#converting first three columns to datetime and rest to categorical data types

for count,column in enumerate(df_viz.columns):
    if count <=2:
        df_viz[column] = pd.to_datetime(df_viz[column])
    else:
        df_viz[column] = df_viz[column].astype('category')

# %%
#checking datatypes

df_viz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294946 entries, 0 to 294945
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   cdc_report_dt       294946 non-null  datetime64[ns]
#  1   pos_spec_dt         294946 non-null  datetime64[ns]
#  2   onset_dt            294946 non-null  datetime64[ns]
#  3   current_status      294946 non-null  category
#  4   sex                 294946 non-null  category
#  5   age_group           294946 non-null  category
#  6   race_and_ethnicity  294946 non-null  category
#  7   hosp_yn             294946 non-null  category
#  8   icu_yn              294946 non-null  category
#  9   death_yn            294946 non-null  category
#  10  medcond_yn          294946 non-null  category
#  11  death_with_medcond  294946 non-null  category
# dtypes: category(9), datetime64[ns](3)
# memory usage: 9.3 MB

# %%
#dropping the alternate staging columns

df_viz.drop(['death_yn_alt', 'medcond_yn_alt'], axis=1, inplace=True)

# %%
#sorting values by cdc_report_date to look at range of dates

df_viz.sort_values(by='cdc_report_dt', ascending=False)
# Out:
#        cdc_report_dt pos_spec_dt   onset_dt             current_status  \
# 136388    2020-11-19  2020-11-19 2020-11-19  Laboratory-confirmed case
# 136212    2020-11-19  2020-11-18 2020-11-15              Probable Case
# 2193      2020-11-19  2020-11-19 2020-11-19  Laboratory-confirmed case
# 149933    2020-11-19  2020-11-23 2020-11-19  Laboratory-confirmed case
# 2195      2020-11-19  2020-11-19 2020-11-19  Laboratory-confirmed case
# ...              ...         ...        ...                        ...
# 131455    2020-01-15  2020-05-05 2020-01-15  Laboratory-confirmed case
# 148902    2020-01-13  2020-11-16 2020-01-13  Laboratory-confirmed case
# 126166    2020-01-13  2020-04-05 2020-01-13  Laboratory-confirmed case
# 247930    2020-01-01  2020-07-14 2020-01-01  Laboratory-confirmed case
# 25521     2020-01-01  2020-03-15 2020-01-01  Laboratory-confirmed case
#
#            sex      age_group   race_and_ethnicity hosp_yn icu_yn death_yn  \
# ...

# %%
#removing sex value 'other' with null

df_viz['sex']=df_viz['sex'].replace('Other', np.nan)

# %%
#sex column male and female counts

df_viz['sex'].value_counts()
# Out:
# Female    157155
# Male      137754
# Name: sex, dtype: int64

# %%
#seaborn countplot showing distribution of race and ethnicity
plt.figure(figsize=[7,5]);

tick_range1 = np.arange(0,150000+25000,25000)
base_color = sns.color_palette()[0]
sns.countplot(data=df_viz, y='race_and_ethnicity', color=base_color);
plt.ylabel('')
plt.xticks(tick_range1);

# %%
#seaborn countplot showing distribution of age_group
type_counts=df_viz['age_group'].value_counts()
num_group = type_counts.sum()
max_age = type_counts[0]
max_prop = max_age / num_group

tick_range2 = np.arange(0, max_prop+0.02, 0.02)
ticks2 = ['{:0.1%}'.format(x) for x in tick_range2]

plt.figure(figsize=[8,8]);

sns.countplot(data=df_viz, y='age_group', color=base_color);
plt.xlabel('Percentage')
plt.ylabel('')
plt.xticks(tick_range2*num_group, ticks2);

# %%
#seaborn countplot showing distribution of sex
sex_counts = df_viz['sex'].value_counts()
max_sex=sex_counts[0]
n_sex = sex_counts[0] + sex_counts[1]
prop_sex = max_sex / n_sex
ticks = np.arange(0,prop_sex+0.08, 0.08)
ticks_fmt = ['{:0.1%}'.format(x) for x in ticks]

plt.figure(figsize=[8,8]);

sns.countplot(data=df_viz, y='sex', color=base_color);
plt.xlabel('Percentage')
plt.ylabel('')
plt.xticks(n_sex*ticks,ticks_fmt);

# %%
#seaborn countplot showing distribution of age and sex in dataframe

plt.figure(figsize=[8,5])

sns.countplot(y='age_group', hue="sex",
            palette="pastel", edgecolor=".6",
            data=df_viz);
plt.title('Distribution of Age and Sex', weight='bold', fontsize=14);
plt.ylabel('')
plt.xlabel('Count');

# %%
#seaborn plot showing distribution of age by race

plt.figure(figsize=[16,10])

sns.countplot(y='age_group', hue="race_and_ethnicity",
            palette="pastel", edgecolor=".6",
            data=df_viz);

# %%
#linear and logarithmic scaling of ages if person survived or died

plt.figure(figsize=[14,8])


plt.subplot(2,1,1)
log_ticks=[10, 30, 100, 300, 1000, 3000, 10000]
sns.countplot(y='age_group', hue="death_yn",
            palette="pastel", edgecolor=".6",
            data=df_viz);
plt.xscale('log')
plt.xticks(log_ticks, log_ticks);
plt.legend(title='Died');
plt.ylabel('')
plt.xlabel('Count')
plt.title('Logarithmic Scaling of Ages in COVID-19 Dataset', fontsize=14, weight='bold')

plt.subplot(2,1,2)
sns.countplot(y='age_group', hue="death_yn",
            palette="pastel", edgecolor=".6",
            data=df_viz);
plt.legend(title='Died');
plt.title('Linear Scaling of Ages in COVID-19 Dataset', fontsize=14, weight='bold');
plt.ylabel('')
plt.xlabel('Count')
plt.tight_layout()

# %%
#linear and logarithmic plot of ethnicies survivied vs. died

plt.figure(figsize=[14,8])

plt.subplot(2,1,1)
log_ticks2=[30, 100, 300, 1000, 3000, 10000, 30000, 100000]
sns.countplot(y='race_and_ethnicity', hue="death_yn",
            palette="pastel", edgecolor=".6",
            data=df_viz);
plt.xscale('log')
plt.legend(title='Died')
plt.title('Logarithmic Scaling of Ethnicities in Dataset vs. Deaths', fontsize=14, weight='bold')
plt.ylabel('')
plt.xticks(log_ticks2, log_ticks2);

plt.subplot(2,1,2)
plt.title('Linear Scaling of Ethnicities in Dataset vs. Deaths', fontsize=14, weight='bold')
sns.countplot(y='race_and_ethnicity', hue="death_yn",
            palette="pastel", edgecolor=".6",
            data=df_viz);
plt.ylabel('')
plt.legend(title='Died');
plt.tight_layout()

# %%
#creating death_race dataframe querying df_viz where every patient died

death_race = df_viz.query('death_yn == "Yes"')

# %%
#value counts of deaths if person had a preexisting medical condition

death_race['death_with_medcond'].value_counts()
# Out:
# Yes    12718
# No       976
# Name: death_with_medcond, dtype: int64

# %%
#plot of people dying with a preexisting medical condition vs people that died without a recorded diagnosis

plt.figure(figsize=[14,7])

sns.countplot(data=death_race, y='death_with_medcond');

# %%
#counts of ethnicities in death_race dataframe

death_counts1 = death_race['race_and_ethnicity'].value_counts()
death_counts1
# Out:
# White, Non-Hispanic                                     8066
# Black, Non-Hispanic                                     2281
# Hispanic/Latino                                         2106
# Asian, Non-Hispanic                                      574
# Multiple/Other, Non-Hispanic                             472
# American Indian/Alaska Native, Non-Hispanic              115
# Native Hawaiian/Other Pacific Islander, Non-Hispanic      80
# Name: race_and_ethnicity, dtype: int64

# %%
#creating death with medical conditions dataframe that only focuses on people dying that
#already had a preexisting medical condition

death_medcond_race = death_race.query('death_with_medcond == "Yes"')

# %%
#counts of ethnicity from the death_medcond_race dataframe

death_counts3= death_medcond_race['race_and_ethnicity'].value_counts()
death_counts3
# Out:
# White, Non-Hispanic                                     7536
# Black, Non-Hispanic                                     2192
# Hispanic/Latino                                         1862
# Asian, Non-Hispanic                                      512
# Multiple/Other, Non-Hispanic                             435
# American Indian/Alaska Native, Non-Hispanic              110
# Native Hawaiian/Other Pacific Islander, Non-Hispanic      71
# Name: race_and_ethnicity, dtype: int64

# %%
#counts of age group from the death_medcond_race dataframe

death_counts4=death_medcond_race['age_group'].value_counts()
death_counts4
# Out:
# 80+ Years        4801
# 70 - 79 Years    3173
# 60 - 69 Years    2560
# 50 - 59 Years    1400
# 40 - 49 Years     491
# 30 - 39 Years     200
# 20 - 29 Years      68
# 10 - 19 Years      19
# 0 - 9 Years         6
# Name: age_group, dtype: int64

# %%
#counts of age group from the death_race dataframe (deaths overall)

death_counts2 = death_race['age_group'].value_counts()
death_counts2
# Out:
# 80+ Years        5102
# 70 - 79 Years    3354
# 60 - 69 Years    2726
# 50 - 59 Years    1565
# 40 - 49 Years     580
# 30 - 39 Years     234
# 20 - 29 Years      93
# 10 - 19 Years      30
# 0 - 9 Years        10
# Name: age_group, dtype: int64

# %%
#race_counts overall from wrangled dataframe

race_counts = df_viz['race_and_ethnicity'].value_counts()
race_counts
# Out:
# White, Non-Hispanic                                     165999
# Hispanic/Latino                                          76584
# Black, Non-Hispanic                                      31370
# Asian, Non-Hispanic                                       9440
# Multiple/Other, Non-Hispanic                              7964
# Native Hawaiian/Other Pacific Islander, Non-Hispanic      2316
# American Indian/Alaska Native, Non-Hispanic               1273
# Name: race_and_ethnicity, dtype: int64

# %%
#age_counts overall from wrangled dataframe

age_counts = df_viz['age_group'].value_counts()
age_counts
# Out:
# 20 - 29 Years    53050
# 50 - 59 Years    45814
# 30 - 39 Years    45179
# 40 - 49 Years    45010
# 60 - 69 Years    35042
# 10 - 19 Years    27154
# 70 - 79 Years    20834
# 80+ Years        14559
# 0 - 9 Years       8304
# Name: age_group, dtype: int64

# %%
#creating proportion race dataframe adding an index as well as taking death_counts 1
#which is counts of ethnicies in death_race dataframe divided by race_counts multiplied by 100 to get
#a percentage of people that died

proportion_race = (death_counts1 / race_counts)*100
proportion_race = proportion_race.reset_index()
proportion_race
# Out:
#                                                index  race_and_ethnicity
# 0        American Indian/Alaska Native, Non-Hispanic            9.033778
# 1                                Asian, Non-Hispanic            6.080508
# 2                                Black, Non-Hispanic            7.271278
# 3                                    Hispanic/Latino            2.749922
# 4                       Multiple/Other, Non-Hispanic            5.926670
# 5  Native Hawaiian/Other Pacific Islander, Non-Hi...            3.454231
# 6                                White, Non-Hispanic            4.859065

# %%
#renaming the columns that were created in the proportion_race dataframe to more appropriate column headings

proportion_race = proportion_race.rename(columns={'index':'race_and_ethnicity', 'race_and_ethnicity':'death_percentage'})

# %%
#how proportion_race dataframe looks so far

proportion_race
# Out:
#                                   race_and_ethnicity  death_percentage
# 0        American Indian/Alaska Native, Non-Hispanic          9.033778
# 1                                Asian, Non-Hispanic          6.080508
# 2                                Black, Non-Hispanic          7.271278
# 3                                    Hispanic/Latino          2.749922
# 4                       Multiple/Other, Non-Hispanic          5.926670
# 5  Native Hawaiian/Other Pacific Islander, Non-Hi...          3.454231
# 6                                White, Non-Hispanic          4.859065

# %%
#sorting the values in the death_percentage column and resetting index in proportion_race

proportion_race = proportion_race.sort_values('death_percentage')
proportion_race = proportion_race.reset_index(drop=True)

# %%
#how dataframe looks after sorting

proportion_race
# Out:
#                                   race_and_ethnicity  death_percentage  \
# 0                                    Hispanic/Latino          2.749922
# 1  Native Hawaiian/Other Pacific Islander, Non-Hi...          3.454231
# 2                                White, Non-Hispanic          4.859065
# 3                       Multiple/Other, Non-Hispanic          5.926670
# 4                                Asian, Non-Hispanic          6.080508
# 5                                Black, Non-Hispanic          7.271278
# 6        American Indian/Alaska Native, Non-Hispanic          9.033778
#
#    death_medcond_percentage
# 0                  2.569230
# 1                  3.319454
# 2                  4.296097
# 3                  5.286507
# 4                  5.603858
# 5                  6.955136
# 6                  8.017478

# %%
#creating order_race list to be used on following plot

order_race = []
for val in proportion_race['race_and_ethnicity']:
    order_race.append(val)
order_race
# Out:
# ['Hispanic/Latino',
#  'Native Hawaiian/Other Pacific Islander, Non-Hispanic',
#  'White, Non-Hispanic',
#  'Multiple/Other, Non-Hispanic',
#  'Asian, Non-Hispanic',
#  'Black, Non-Hispanic',
#  'American Indian/Alaska Native, Non-Hispanic']

# %%
#this loop populates values in the med_cond_prop_race list that shows the percentages of people of race
#that died having a preexisting condition by ethnicity

med_cond_prop_race = []
for i,val in enumerate(death_counts3):
    med_cond_prop_race.append(death_counts3[i]/death_counts1[i])
med_cond_prop_race
# Out:
# [0.9342920902553931,
#  0.9609820254274442,
#  0.8841405508072174,
#  0.89198606271777,
#  0.9216101694915254,
#  0.9565217391304348,
#  0.8875]

# %%
#creathing a death_medcond_percentage column that multiplies the values of the death_percentage column
#with the values in the med_cond_prop_race list

proportion_race['death_medcond_percentage'] = proportion_race['death_percentage'] * med_cond_prop_race

# %%
#creating proportion_age dataframe taking death counts by age and diving it by the age_counts overall in 
#df_viz dataframe and multiplying it by 100 to get percentage

proportion_age = (death_counts2/ age_counts)*100
proportion_age = proportion_age.reset_index()
proportion_age
# Out:
#            index  age_group
# 0    0 - 9 Years   0.120424
# 1  10 - 19 Years   0.110481
# 2  20 - 29 Years   0.175306
# 3  30 - 39 Years   0.517940
# 4  40 - 49 Years   1.288603
# 5  50 - 59 Years   3.415986
# 6  60 - 69 Years   7.779236
# 7  70 - 79 Years  16.098685
# 8      80+ Years  35.043616

# %%
#for loop renaming columns; taking a different approach for this dataframe

for x in proportion_age.columns:
    if x == 'index':
        proportion_age = proportion_age.rename(columns={x:'age_group1'})
    else:
        proportion_age = proportion_age.rename(columns={x:'death_percentage'})

# %%
#the look of the proportion_age dataframe so far

proportion_age
# Out:
#       age_group1  death_percentage  death_medcond_percentage
# 0    0 - 9 Years          0.120424                  0.113319
# 1  10 - 19 Years          0.110481                  0.104519
# 2  20 - 29 Years          0.175306                  0.164631
# 3  30 - 39 Years          0.517940                  0.463333
# 4  40 - 49 Years          1.288603                  1.090869
# 5  50 - 59 Years          3.415986                  2.919646
# 6  60 - 69 Years          7.779236                  5.688044
# 7  70 - 79 Years         16.098685                 10.195834
# 8      80+ Years         35.043616                 21.026169

# %%
#this loop populates values in the med_cond_prop_age list that shows the percentages of people of race
#that died having a preexisting condition by age

med_cond_prop_age = []
for i,val in enumerate(death_counts4):
    med_cond_prop_age.append(death_counts4[i]/death_counts2[i])
med_cond_prop_age
# Out:
# [0.9410035280282242,
#  0.9460345855694693,
#  0.9391049156272927,
#  0.8945686900958466,
#  0.846551724137931,
#  0.8547008547008547,
#  0.7311827956989247,
#  0.6333333333333333,
#  0.6]

# %%
#creating death_medcond_percentage column by multiplying the values in the death_percentage column by the
#med_cond_prop_age list

proportion_age['death_medcond_percentage'] = proportion_age['death_percentage'] * med_cond_prop_age

# %%
#linear and logarithmic stacked bar graph of death by age illustrating deaths overall vs deaths with individuals that
#had a preexisting condition

plt.figure(figsize=[14,8])
percent_ticks=np.arange(0,35+5,5)
percent_ticks_fmt=[]
for i,val in enumerate(percent_ticks):
    percent_ticks_fmt.append(percent_ticks[i].astype(str)+'%')
    
log_ticks=[0.1, 0.3, 1.0, 3.0, 10, 30]
log_ticks_fmt=[]
for i,val in enumerate(log_ticks):
    log_ticks_fmt.append(str(log_ticks[i])+'%')

plt.subplot(2,1,1)
sns.barplot(data=proportion_age, y='age_group1', x='death_percentage', color=base_color);
sns.barplot(data=proportion_age, y='age_group1', x='death_medcond_percentage', color=sns.color_palette()[1]);
plt.title("Death by Age, Linear Scaling", fontsize=14, weight='bold')
plt.xlabel('Death with Preexisting Medical Condition (orange) vs. Death overall (blue)'.title(), weight='bold');
plt.ylabel('')
plt.xticks(percent_ticks,percent_ticks_fmt);

plt.subplot(2,1,2)
sns.barplot(data=proportion_age, y='age_group1', x='death_percentage', color=base_color);
sns.barplot(data=proportion_age, y='age_group1', x='death_medcond_percentage', color=sns.color_palette()[1]);
plt.title("Death by Age, Logarithmic Scaling", fontsize=14, weight='bold')
plt.xlabel('Death with Preexisting Medical Condition (orange) vs. Death overall (blue)'.title(), weight='bold');
plt.ylabel('');
plt.xscale('log')
plt.xticks(log_ticks, log_ticks_fmt)
plt.tight_layout()

# %%
#stacked bar graph of death by race illustrating deaths overall vs deaths with individuals that
#had a preexisting condition

plt.figure(figsize=[14,8])

percent_ticks=np.arange(0,10+1, 1)
percent_ticks_fmt=[]
for i,val in enumerate(percent_ticks):
    percent_ticks_fmt.append(percent_ticks[i].astype(str)+ '%')

sns.barplot(data=proportion_race, y='race_and_ethnicity', x='death_percentage', color=base_color, order=order_race);
sns.barplot(data=proportion_race, y='race_and_ethnicity', x='death_medcond_percentage', color=sns.color_palette()[1],
            order=order_race);
plt.title("Death by Ethnic Group", fontsize=14, weight='bold')
plt.xticks(percent_ticks, percent_ticks_fmt)
plt.ylabel('')
plt.xlabel('Death with Preexisting Medical Condition (orange) vs. Death overall (blue)'.title(), weight='bold');
plt.tight_layout()
